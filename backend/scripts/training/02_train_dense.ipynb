# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# ==========================================
# 1. CONFIGURATION & PATHS
# ==========================================
# Assuming this script runs inside the 'scripts/' folder
BASE_DIR = os.path.dirname(os.path.abspath(__file__)) if '__file__' in locals() else os.path.abspath('../..')

TRAIN_CSV = os.path.join(BASE_DIR, 'dataset', 'train_landmarks.csv')
VAL_CSV = os.path.join(BASE_DIR, 'dataset', 'val_landmarks.csv')
MODEL_SAVE_PATH = os.path.join(BASE_DIR, 'models', 'kiosk_face_model_2.keras')

EPOCHS = 40
BATCH_SIZE = 32

# Ensure the models directory exists
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)

# %%
# ==========================================
# 2. DATA LOADING (From CSV)
# ==========================================
print("Loading Landmark CSV files...")

# Load the data using Pandas
train_df = pd.read_csv(TRAIN_CSV)
val_df = pd.read_csv(VAL_CSV)

# Extract Labels (the first column) and convert to integer arrays
y_train = train_df['label_idx'].values.astype(np.int32)
y_val = val_df['label_idx'].values.astype(np.int32)

# Extract Features (the remaining 1404 columns) and convert to float arrays
X_train = train_df.drop('label_idx', axis=1).values.astype(np.float32)
X_val = val_df.drop('label_idx', axis=1).values.astype(np.float32)

# Figure out how many classes we have dynamically
NUM_CLASSES = len(np.unique(y_train))
print(f"Found {NUM_CLASSES} distinct classes.")
print(f"Training samples: {X_train.shape[0]} | Validation samples: {X_val.shape[0]}")
print(f"Input feature size: {X_train.shape[1]} (Should be 1404)")
# Out:
# Loading Landmark CSV files...
# Found 15 distinct classes.
# Training samples: 1192 | Validation samples: 286
# Input feature size: 1404 (Should be 1404)

# %%
# ==========================================
# 3. ARCHITECTURE DESIGN (Deep Dense Network)
# ==========================================

# MediaPipe Face Mesh outputs 468 landmarks. Each has an x, y, and z coordinate.
# 468 * 3 = 1404 inputs
inputs = tf.keras.Input(shape=(1404,)) 

# Building a custom Deep Dense Network (Fulfills "Training from Scratch" rubric)
x = layers.Dense(128, activation='relu')(inputs)
x = layers.Dropout(0.15)(x) # 15% Dropout
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.1)(x)  # 10% Dropout

# Final output layer
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

# Compile the model (Manual definition required by rubric)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1404)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       179,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 15)             │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 189,071 (738.56 KB)
#  Trainable params: 189,071 (738.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ==========================================
# 4. TRAINING THE MODEL
# ==========================================
print("\nStarting Training...")
history = model.fit(
    X_train, y_train,              # Pass the raw arrays
    validation_data=(X_val, y_val), 
    batch_size=32,
    epochs=50                      # MLPs train very fast, you can comfortably do 30-50 epochs
)
# Out:
# Starting Training...
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0956 - loss: 2.7174 - val_accuracy: 0.1014 - val_loss: 2.6844
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1292 - loss: 2.6448 - val_accuracy: 0.1084 - val_loss: 2.6361
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1527 - loss: 2.5403 - val_accuracy: 0.0874 - val_loss: 2.5946
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.1661 - loss: 2.4700 - val_accuracy: 0.1294 - val_loss: 2.5643
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2005 - loss: 2.4043 - val_accuracy: 0.1503 - val_loss: 2.5632
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.2458 - loss: 2.3198 - val_accuracy: 0.1329 - val_loss: 2.5122
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.2500 - loss: 2.2769 - val_accuracy: 0.2098 - val_loss: 2.4914
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2827 - loss: 2.1970 - val_accuracy: 0.2867 - val_loss: 2.4863
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3045 - loss: 2.1661 - val_accuracy: 0.3112 - val_loss: 2.4493
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3515 - loss: 2.0521 - val_accuracy: 0.2622 - val_loss: 2.3605
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3700 - loss: 1.9927 - val_accuracy: 0.3252 - val_loss: 2.2505
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3784 - loss: 1.9203 - val_accuracy: 0.3322 - val_loss: 2.1690
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3993 - loss: 1.8981 - val_accuracy: 0.3497 - val_loss: 2.1417
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4094 - loss: 1.8236 - val_accuracy: 0.3252 - val_loss: 2.1527
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4488 - loss: 1.7802 - val_accuracy: 0.3531 - val_loss: 2.0721
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4715 - loss: 1.6927 - val_accuracy: 0.3287 - val_loss: 2.0284
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4597 - loss: 1.6880 - val_accuracy: 0.3741 - val_loss: 2.0447
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4950 - loss: 1.6255 - val_accuracy: 0.3776 - val_loss: 1.9628
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4857 - loss: 1.6175 - val_accuracy: 0.3601 - val_loss: 1.9597
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4950 - loss: 1.5780 - val_accuracy: 0.3671 - val_loss: 1.8713
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4924 - loss: 1.5806 - val_accuracy: 0.3671 - val_loss: 1.9461
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5008 - loss: 1.5335 - val_accuracy: 0.3881 - val_loss: 1.9117
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5151 - loss: 1.4736 - val_accuracy: 0.3811 - val_loss: 1.8476
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5193 - loss: 1.4716 - val_accuracy: 0.3811 - val_loss: 1.8839
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5243 - loss: 1.4394 - val_accuracy: 0.3846 - val_loss: 1.7984
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5344 - loss: 1.4229 - val_accuracy: 0.3916 - val_loss: 1.8096
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5470 - loss: 1.4059 - val_accuracy: 0.4091 - val_loss: 1.7620
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5361 - loss: 1.4127 - val_accuracy: 0.4126 - val_loss: 1.8623
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5411 - loss: 1.3840 - val_accuracy: 0.3811 - val_loss: 1.8433
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5638 - loss: 1.3230 - val_accuracy: 0.3601 - val_loss: 1.8400
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5579 - loss: 1.3187 - val_accuracy: 0.3776 - val_loss: 1.7629
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5772 - loss: 1.3002 - val_accuracy: 0.4126 - val_loss: 1.7490
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5545 - loss: 1.3189 - val_accuracy: 0.4406 - val_loss: 1.7865
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5671 - loss: 1.2849 - val_accuracy: 0.4196 - val_loss: 1.7607
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5663 - loss: 1.2792 - val_accuracy: 0.4056 - val_loss: 1.8224
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5805 - loss: 1.2258 - val_accuracy: 0.3916 - val_loss: 1.8019
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5898 - loss: 1.2416 - val_accuracy: 0.4580 - val_loss: 1.7438
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5663 - loss: 1.2517 - val_accuracy: 0.4196 - val_loss: 1.7973
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5856 - loss: 1.2268 - val_accuracy: 0.4266 - val_loss: 1.7164
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5864 - loss: 1.2134 - val_accuracy: 0.4091 - val_loss: 1.7906
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5872 - loss: 1.2044 - val_accuracy: 0.4476 - val_loss: 1.7589
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5839 - loss: 1.1708 - val_accuracy: 0.4056 - val_loss: 1.8593
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5965 - loss: 1.1404 - val_accuracy: 0.4021 - val_loss: 1.7693
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6124 - loss: 1.1489 - val_accuracy: 0.3776 - val_loss: 1.7854
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6065 - loss: 1.1638 - val_accuracy: 0.4301 - val_loss: 1.7998
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6091 - loss: 1.1739 - val_accuracy: 0.4545 - val_loss: 1.6836
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6074 - loss: 1.1533 - val_accuracy: 0.3986 - val_loss: 1.7577
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6141 - loss: 1.1279 - val_accuracy: 0.4755 - val_loss: 1.6867
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6342 - loss: 1.0896 - val_accuracy: 0.4441 - val_loss: 1.8547
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6351 - loss: 1.0773 - val_accuracy: 0.4231 - val_loss: 1.8006

# %%
# ==========================================
# 5. MODEL PERFORMANCE EVALUATION (Plotting)
# ==========================================
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 6))

# Plot Accuracy
plt.subplot(1, 2, 1)

epochs_range = range(len(acc))

plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show() # Fulfills grading requirement: "Analysis of training/validation curves"

# %%
# ==========================================
# 6. SAVING THE FINAL DELIVERABLE
# ==========================================
model.save(MODEL_SAVE_PATH)
print(f"\n✅ Training complete! Model successfully saved to: {MODEL_SAVE_PATH}")
# Out:
# ✅ Training complete! Model successfully saved to: /Users/cxnner05/Documents/projects/ml-finals/backend/models/kiosk_face_model_2.keras
